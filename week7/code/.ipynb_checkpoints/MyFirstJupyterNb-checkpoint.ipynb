# %%
a = "this is python!"; print(a) #python kernel
# Out:
# this is python!

# %%
a <- "this is R!"; cat(a) #R kernel
# Out:
# this is R!

# %%
import matplotlib.pyplot as p #python kernel
import scipy as sc

x = sc.arange(0,5,0.1); y = sc.sin(x)
p.plot(x,y); p.show()
# Out:
# /var/folders/fd/841x8thx2l16j73klxr1t86m0000gn/T/ipykernel_7177/4081053479.py:4: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   x = sc.arange(0,5,0.1); y = sc.sin(x)
# /var/folders/fd/841x8thx2l16j73klxr1t86m0000gn/T/ipykernel_7177/4081053479.py:4: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   x = sc.arange(0,5,0.1); y = sc.sin(x)

# %%
require(ggplot2)
library(repr)# to resize plot within jupyter - this package is part of IRKernel
options(repr.plot.width=3.3,repr.plot.height=2.5)

x <- seq(0, 5, 0.1); y <- sin(x)
qplot(x, y, geom = "line") # large figure
# Out:
# plot without title
